# %% [markdown]
# #Pillow Library
#
# Some useful commands:
#
#
# - .show()
# - .size()
# - .resize()
# - .rotate()
#
# RGBA Tools:
# - .putred()
# - .putblue()
# - .putgreen()
# - .putalpha()

# %%
from PIL import Image

# %%
photo = Image.open('example.jpeg')
photo.show()
