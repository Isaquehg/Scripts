# %%
stock_prices = [("apple", 300), ("google",500), ("microsft",250)]
for (brand,price) in stock_prices:
  print(brand)
# Out:
# apple
# google
# microsft

# %%
work_hours = [("Larry",200),("Darry",280),("John",520),("Bob", 750)]

def employee_check(work_hours):
  current_max = 0
  employee_of_month = ""

  for (employee, hours) in work_hours:
    if hours > current_max:
      current_max = hours
      employee_of_month = employee
    else:
      pass
  return (employee_of_month, current_max)

#UNPACKED TUPLE through ITEM1,ITEM2 = X(tup,tup)
name, hours = employee_check(work_hours)
print(name)
print(hours)
# Out:
# Bob
# 750
