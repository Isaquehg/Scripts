# %% [markdown]
# #Working with CSV files
# Steps:
# - Open the file
# - Read/write it (csv.reader()/csv.writer())
# - Convert into a array

# %%
import csv

# %%
#READING DATA
data = open('exemple.csv', encoding = 'utf-8')
csv_file = csv.reader(data)
file_lines = list(csv_file)#This will organize by collumns

# %%
#accessing data
file_lines[1][1]

# %%
#WRITING DATA
file_output = open('to_save_file.csv', mode = 'w', newline = ' ')
csv_writer = csv.writer(file_output, delimiter = ';')
csv_writer.writerow(['name1'; 'name2'; 'name3'])
#to use WRITEROWS, we have to use list of lists!
file_ouput.close()
