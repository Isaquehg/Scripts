# %%
#NEW LINE: \n
stuff ="Larry\nDarry"
print(stuff)
# Out:
# Larry
# Darry

# %%
#OPEN FILE: stuf = open(text.txt, "mode")
#file oppener
#NOT FINISHED!
fname = input("Enter a file name:")
try:
  letter = input("Enter a letter or word:")
  hand = open("fname", "r")
  count = 0
  for line in fname:
    if line.startwith(letter):
      count = count + 1
      print("There´s", count, letter, "inside the doccument.")
except:
  print:("File", fname, "could not be found.")
# Out:
# Enter a file name:/abc.txt
# Enter a letter or word:a

# %%
x = open("/abc.txt", "r")
print(x.read())
# Out:
# abc
# 	abc
# ABC

# %%
#Part I

def mytrim(word):
  newword = ""
  for c in word:
    if (c == "," or c == " " or c == "´" or c== "~" or c == "." or c == "!" or c == "?"):
      continue
    else:
      newword = newword + c
  newword = newword.upper().split()
  return(newword)

#Part II

search = input("Enter a letter or word: ")
search = search.strip()
counter = 0

userfile = input("Enter a file:")
f = open("userfile", "a+")
for line in f:
  list = line.split()
  print(list)
  for word in list:
    if mytrim(word) == search:
      counter = counter + 1
if counter == 0:
  print("\nThe word", (search), "could not be found!")
else:
  print("The word\letter", search, "was found", counter, "times.")
# Out:
# Enter a letter or word: abc
# Enter a file:/abc.txt
#
# The word abc could not be found!
