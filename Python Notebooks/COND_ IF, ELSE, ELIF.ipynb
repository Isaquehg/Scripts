# %%
x = 5
if x > 6:
  print ("bigger")
else:
  print ("smaller")
print("Well Done!")
# Out:
# smaller
# Well Done!

# %%
x = 0
if x > 10:
  print("BIG")
elif 5 < x <= 10:
  print("MEDIUM")
else:
  print ("SMALL")
print("WELL DONE!")
# Out:
# SMALL
# WELL DONE!

# %%
x = 11
if x < 2:
 print("Small")
elif x < 10:
  print("Medium")
elif x < 20:
  print("Big")
elif x < 30:
  print("Huge")
else:
  print("Enourmous")
print("Well Done!")
# Out:
# Big
# Well Done!
