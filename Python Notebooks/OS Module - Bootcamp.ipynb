# %%
#This command shows where my python file is
#It works only for notebooks!
pwd
# Out:
# '/content'

# %%
f = open("practice.txt","w+")
f.write("This is a test file!!")
f.close()

# %%
import os
os.getcwd()#This command works within all the environments
# Out:
# '/content'

# %%
#listdir makes a list of the current directory content
#We can use for a specific folde like os.listdir("C:\\Users")
os.listdir()
# Out:
# ['.config', 'drive', 'sample_data']

# %%
#MOVING FILES
#shutil.move("source","C:\\Users\\Destination")
import shutil
shutil.move('sample_data.txt', '/content/drive')

# %%
#for deleting files, we need to use pip install send2trash library for safer results
import send2trash
send2trash.send2trash("file.txt")

# %%
#os.walk
#we can use walk for going to multiple folder and directories using for loop!
