# %%
import datetime
#Here we can set time by using time(hour, minute, sec, etc)
#If we don´t use value for a specific paramether, it´s gonna be set to zero.
mytime = datetime.time(2,2)

# %%
mytime.minute
# Out:
# 2

# %%
print(mytime)
# Out:
# 02:02:00

# %%
#to use the current date, use: today = datetime.date.today()
today = datetime.date(2021, 1, 25)
print(today)
# Out:
# 2021-01-25

# %%
today.ctime()#all the paramethers
# Out:
# 'Mon Jan 25 00:00:00 2021'
