# %%
#SPLIT Function(Diving a String):
abc = "I´m a Programmer"
stuff = abc.split()
print(stuff)
print(stuff[2])
for x in stuff:
  print(x)
#Here below, we can specify where I wanna split(commas in this exemple).
anything = "Names;spaced;with;commas"
etc = anything.split(";")
print(etc)
# Out:
# ['I´m', 'a', 'Programmer']
# Programmer
# I´m
# a
# Programmer
# ['Names', 'spaced', 'with', 'commas']

# %%
#wORKED EXCERCISE
