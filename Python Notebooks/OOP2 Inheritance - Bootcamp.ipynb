# %%
class Animal():
  def __init__(self):
    print("Animal created!")
  
  def what_is_it(self):
    print("This is a animal")

  def eat(self):
    print("It´s eating...")

# %%
class Dog(Animal):
  def __init__(self):
    Animal.__init__(self)
    print("DOG created!!")

# %%
mydog = Dog()
# Out:
# Animal created!
# DOG created!!
