# %%
def greet(lang):
  if lang == "es":
    print("Holla!")
  elif lang == "deut":
    print("Hallo!")
  else:
    print("Hello!")
greet("es")
greet("deut")
greet("en")
greet("abc")
greet("blablabla")
# Out:
# Holla!
# Hallo!
# Hello!
# Hello!
# Hello!

# %%
def greet(lang):
  if lang == "es":
    return"Holla!"
  elif lang == "deut":
    return"Hallo!"
  else:
    return"Hello!"
x = input("What´s your language?\nChoose among these ones:\n es, deut or other: ")
greeting = greet(x)
print(greeting)
# Out:
# What´s your language?
# Choose among these ones:
#  es, deut or otherother
# Hello!

# %%
def twosum(a, b):
  added = a + b
  return added
x = twosum(20, 10)
print("x")
# Out:
# 30
