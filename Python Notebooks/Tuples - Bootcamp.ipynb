# %%
#PARENTHESES
#The main difference between lists is
#the imutability of the tuples!
l = ["a", "a", "b"]#list
t = ("a", "a", "b")#tuple

#Tuple´s methods: .index() and .count()

print(t.index("a")) #Shows the index of the FIRST time this element appears
print(t.count("a"))
print(t) #Counts how many times this appears
